# %% [markdown]
# # Test set evaluation on stochastic models
#
# The purpose of this experiment is to measure how the **validation accuracy** changes accross a single model trained with different values of **alpha**.
#
# It will solely examine the models' classification performance and not their masking performance.

# %%
import sys
sys.path.append('..')

import warnings
warnings.filterwarnings('once')

from utils.plotting import *

# %matplotlib inline
# Out:
# /home/thanos/.envs/dl/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/thanos/.envs/dl/lib/python3.5/site-packages/tensorflow/python/keras/backend.py:5605: ResourceWarning: unclosed file <_io.TextIOWrapper name='/home/thanos/.keras/keras.json' mode='r' encoding='UTF-8'>
#   _config = json.load(open(_config_path))
# /home/thanos/.envs/dl/lib/python3.5/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])

# %% [markdown]
# ## 1. Compare each each set of experiments
#
# First let's load the baseline.

# %%
baseline_loc = '../results/cifar10/seeker/default/baseline.txt'
with open(baseline_loc) as f:
    baseline = float(f.read())
print('Baseline accuracy: {:.2f}%'.format(baseline * 100))
# Out:
# Baseline accuracy: 65.37%

# %% [markdown]
# ### a) ST1

# %%
result_dir = '../results/cifar10/hns/stochastic/st1/full_training_10/'
st1 = read_results(result_dir)

plot_all_results(st1, baseline=baseline)
plt.title('Straight-Through v1')
# Out:
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/st1/full_training_10/1/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/st1/full_training_10/10/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/st1/full_training_10/2/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/st1/full_training_10/3/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/st1/full_training_10/4/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/st1/full_training_10/5/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/st1/full_training_10/6/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/st1/full_training_10/7/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/st1/full_training_10/8/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/st1/full_training_10/9/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# Text(0.5, 1.0, 'Straight-Through v1')

# %%
plot_average_results(st1, baseline=baseline)
plt.title('Straight-Through v1')
# Out:
# Text(0.5, 1.0, 'Straight-Through v1')

# %% [markdown]
# Pretty standard performance. The models are very low-variance, with the exception of a single model whose performance droped significantly for low alpha (probably it collapsed to masking everything). If the training lasted longer maybe it could have recovered.
#
# ### b) ST2

# %%
result_dir = '../results/cifar10/hns/stochastic/st2/full_training_10/'
st2 = read_results(result_dir)

plot_all_results(st2, baseline=baseline)
plt.title('Straight-Through v2')
# Out:
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/st2/full_training_10/1/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/st2/full_training_10/10/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/st2/full_training_10/2/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/st2/full_training_10/3/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/st2/full_training_10/4/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/st2/full_training_10/5/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/st2/full_training_10/6/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/st2/full_training_10/7/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/st2/full_training_10/8/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/st2/full_training_10/9/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# Text(0.5, 1.0, 'Straight-Through v2')

# %%
plot_average_results(st2, baseline=baseline)
plt.title('Straight-Through v2')
# Out:
# Text(0.5, 1.0, 'Straight-Through v2')

# %% [markdown]
# Again, pretty high levels of performance.
#
# ### c) SA
#
# #### Rate=0.1

# %%
result_dir = '../results/cifar10/hns/stochastic/sa/rate_0.1/full_training_10/'
sa_01 = read_results(result_dir)

plot_all_results(sa_01, baseline=baseline)
plt.title('Slope-Annealing, Rate=0.1')
# Out:
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_0.1/full_training_10/1/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_0.1/full_training_10/10/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_0.1/full_training_10/2/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_0.1/full_training_10/3/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_0.1/full_training_10/4/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_0.1/full_training_10/5/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_0.1/full_training_10/6/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_0.1/full_training_10/7/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_0.1/full_training_10/8/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_0.1/full_training_10/9/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# Text(0.5, 1.0, 'Slope-Annealing, Rate=0.1')

# %%
plot_average_results(sa_01, baseline=baseline)
plt.title('Slope-Annealing, Rate=0.1')
# Out:
# Text(0.5, 1.0, 'Slope-Annealing, Rate=0.1')

# %% [markdown]
# Same here.
#
# #### Rate=0.5

# %%
result_dir = '../results/cifar10/hns/stochastic/sa/rate_0.5/full_training_10/'
sa_05 = read_results(result_dir)

plot_all_results(sa_05, baseline=baseline)
plt.title('Slope-Annealing, Rate=0.5')
# Out:
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_0.5/full_training_10/1/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_0.5/full_training_10/10/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_0.5/full_training_10/2/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_0.5/full_training_10/3/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_0.5/full_training_10/4/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_0.5/full_training_10/5/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_0.5/full_training_10/6/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_0.5/full_training_10/7/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_0.5/full_training_10/8/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_0.5/full_training_10/9/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# Text(0.5, 1.0, 'Slope-Annealing, Rate=0.5')

# %%
plot_average_results(sa_05, baseline=baseline)
plt.title('Slope-Annealing, Rate=0.5')
# Out:
# Text(0.5, 1.0, 'Slope-Annealing, Rate=0.5')

# %% [markdown]
# #### Rate=1

# %%
result_dir = '../results/cifar10/hns/stochastic/sa/rate_1.0/full_training_10/'
sa_1 = read_results(result_dir)

plot_all_results(sa_1, baseline=baseline)
plt.title('Slope-Annealing, Rate=1')
# Out:
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_1.0/full_training_10/1/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_1.0/full_training_10/10/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_1.0/full_training_10/2/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_1.0/full_training_10/3/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_1.0/full_training_10/4/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_1.0/full_training_10/5/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_1.0/full_training_10/6/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_1.0/full_training_10/7/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_1.0/full_training_10/8/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# ../utils/plotting.py:150: ResourceWarning: unclosed file <_io.BufferedReader name='../results/cifar10/hns/stochastic/sa/rate_1.0/full_training_10/9/results.pkl'>
#   results = pkl.load(open(str(result_file), 'rb'))
# Text(0.5, 1.0, 'Slope-Annealing, Rate=1')

# %%
plot_average_results(sa_1, baseline=baseline)
plt.title('Slope-Annealing, Rate=1')
# Out:
# Text(0.5, 1.0, 'Slope-Annealing, Rate=1')

# %% [markdown]
# #### SA rate comparison

# %%
print('Rate 0.1: ', sa_01['accuracy'].mean())
print('Rate 0.5: ', sa_05['accuracy'].mean())
print('Rate   1: ', sa_1['accuracy'].mean())
# Out:
# Rate 0.1:  0.6197774411816346
# Rate 0.5:  0.6194484914603986
# Rate   1:  0.6108250752875679

# %%
plot_average_results(sa_01, baseline=baseline, label='rate-0.1')
plot_average_results(sa_05, label='rate-0.5')
plot_average_results(sa_1, label='rate-1')

plt.title('Comparison of different slope-annealing rates')
plt.legend()

# %% [markdown]
# We can't make a safe conclusion as to which rates are optimal because their performance seems to be random. The best however results came for a rate of $0.1$.
#
# ### REINFORCE
#
# We know that this estimator doesn't work properly, so we won't bother anymore with it.

# %% [markdown]
# ## 2. Comparative
#
# ### a) mean comparison
#
# we'll first compare the **mean** of all 10 experiments run for each setting.

# %%
plot_average_results(st1, baseline=baseline, label='ST1')
plot_average_results(st2, label='ST2')
plot_average_results(sa_05, label='SA')

plt.title('Comparison of different stochastic estimators')
# Out:
# Text(0.5, 1.0, 'Comparison of different stochastic estimators')

# %% [markdown]
# Besides a few flucturatiuons on the edges, all three estimators seem to exhibit similar behavior on the test set. Initially results seem **much more stable** than their deterministic counterpart.
#
# ### b) best comparison
#
# Now, we'll compare the **best** out of all 10 models for each setting.

# %%
best_st1_idx = st1.groupby('experiment')['accuracy'].sum().idxmax()
best_st2_idx = st2.groupby('experiment')['accuracy'].sum().idxmax()
best_sa_idx = sa_05.groupby('experiment')['accuracy'].sum().idxmax()

best_st1 = st1[st1['experiment'] == best_st1_idx]
best_st2 = st2[st2['experiment'] == best_st2_idx]
best_sa = sa_05[sa_05['experiment'] == best_sa_idx]

plt.plot(best_st1['alpha'], best_st1['accuracy'], label='ST1')
plt.plot(best_st2['alpha'], best_st2['accuracy'], label='ST2')
plt.plot(best_sa['alpha'], best_sa['accuracy'], label='SA')

plt.plot(alphas, [baseline] * 19, label='baseline', c='0.5', ls='--')

plt.legend()

plt.title('Comparison of different stochastic estimators')

ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# %% [markdown]
# Again, there is little we can tell about these estimators from this perspective.
#
# ## Discussion
#
# ### Definitions
#
# These were previously defined on the deterministic validation notebook:
#
#
# > - There are two factors that come into play: **performance** (i.e. how high the accuracy was for a certain model) and **variance** (i.e. if we repeat the experiment how likely are we to expect the same performance.)
# > - There are two types of variance we observed here. Variance of a single model for different values of alpha and the variance for training the same model more than once. When we use the term *variance* we'll refer to **both** types.
# > - We want a model to have **high performance** (i.e. high accuracy) and **low variance** (i.e. few fluctuations in performance).
# > - The performance of a trained seeker, on its own, will be referred to as the **baseline** performance. Obviously, because we are hiding information, the models aren't able to surpass this performance. It will serve as the upper limit for our experiments.
# > - There are two extreme states that the model can get *locked* into, which provide suboptimal solutions:
# >
# >     - The model doesn't hide anything, but classifies correctly.
# >     - The model hides everything, but classifies randomly.
# >
# >     These states will be referred to as **collapses**.
#
# ### Observations
#
# - The choice of estimator had little effect to the classification performance of the models.
# - The above is true both in terms of peak performance and variance.
# - Regarding the rates of the slope-annealing estimators, we couldn't make any safe conclusions as to which is best.
